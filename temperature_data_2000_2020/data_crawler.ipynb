# %%
import polars as pl
import seaborn as sns

# %%
# Read two DataFrame using polars
vietnam_temperature_max_df = pl.read_csv('07. vietnam_tmax.csv', infer_schema_length=10000, ignore_errors = True)
vietnam_temperature_min_df = pl.read_csv('08. vietnam_tmin.csv', infer_schema_length=10000, ignore_errors = True)

print(vietnam_temperature_max_df.head())
print(vietnam_temperature_min_df.head())
# Out:
# shape: (5, 6_982)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ COMCODE02 ┆ DISTCODE0 ┆ DISTCODE0 ┆ PROCODE02 ┆ … ┆ dd_2018.1 ┆ dd_2018.1 ┆ dd_2018.1 ┆ dd_2019. │
# │ ---       ┆ 2         ┆ 4         ┆ ---       ┆   ┆ 2.29      ┆ 2.30      ┆ 2.31      ┆ 01.01    │
# │ i64       ┆ ---       ┆ ---       ┆ i64       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆ i64       ┆ str       ┆           ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 3051913   ┆ 30519     ┆ 158       ┆ 305       ┆ … ┆ 22.981432 ┆ 18.923835 ┆ 17.07619  ┆ 16.95921 │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 2        │
# │ 3051547   ┆ 30515     ┆ 157       ┆ 305       ┆ … ┆ 22.911677 ┆ 18.702532 ┆ 16.869293 ┆ 16.80423 │
# ...

# %%
# Select Quang Binh province: Qu¶ng B×nh
